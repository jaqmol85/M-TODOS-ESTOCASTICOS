# %% [markdown]
# <a href="https://colab.research.google.com/github/jaqmol85/M-TODOS-ESTOCASTICOS/blob/main/Copia_de_EJERCICIO_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 05 – Series de Tiempo A
#
# Para la serie de caudales medios diarios del Río Lebrija (archivo adjunto) se le pide:
# 1. Agregar la serie a:
#
# a. Caudales medios mensuales
# b. Caudales medios anuales
# c. Caudales medios mensuales multianuales

# %%
import datetime
import pandas as pd

# Abrir el archivo en modo lectura
with open('/content/drive/MyDrive/Colab Notebooks/SMWR_LEBRIJA_2.csv.txt', 'r') as file:
    # Leer todas las líneas del archivo
    lines = file.readlines()

# Crear dos listas vacías para almacenar las fechas y los caudales
fechas = []
caudales = []

# Iterar sobre las líneas del archivo
for line in lines:
    # Separar los datos por el caracter de tabulación '\t'
    datos = line.strip().split('\t')
    # Verificar si hay suficientes elementos en la línea
    if len(datos) >= 2:
        # Convertir la primera columna a formato de fecha
        fecha = datetime.datetime.strptime(datos[0], '%d/%m/%Y')
        # Agregar la fecha a la lista de fechas
        fechas.append(fecha)
        # Convertir la segunda columna a punto flotante
        caudal = float(datos[1])
        # Agregar el caudal a la lista de caudales
        caudales.append(caudal)
df = pd.DataFrame(data, columns=['Fecha', 'Caudal'])

# Convertir la columna 'Fecha' en el índice del DataFrame
df.set_index('Fecha', inplace=True)

# Caudales medios mensuales
caudal_medio_mensual = df.resample('M').mean()

# Caudales medios anuales
caudal_medio_anual = df.resample('Y').mean()

# Caudales medios mensuales multianuales
caudal_medio_mensual_multianual = df.resample('M').mean().rolling(window=12, min_periods=1).mean()
# Coeficiente de Asimetría y Coeficiente de Curtosis
coeficiente_asimetria = pd.Series(caudales).skew()
coeficiente_curtosis = pd.Series(caudales).kurtosis()

# Imprimir las fechas y caudales
for i in range(len(fechas)):
    print(f"Fila {i + 1}: Fecha: {fechas[i].strftime('%d/%m/%Y')}, Caudal: {caudales[i]}")

print(f"Coeficiente de Asimetría: {coeficiente_asimetria}")
print(f"Coeficiente de Curtosis: {coeficiente_curtosis}")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Fila 1168: Fecha: 19/03/2003, Caudal: 59.8
# Fila 1169: Fecha: 20/03/2003, Caudal: 82.7
# Fila 1170: Fecha: 21/03/2003, Caudal: 44.7
# Fila 1171: Fecha: 22/03/2003, Caudal: 54.3
# Fila 1172: Fecha: 23/03/2003, Caudal: 51.3
# Fila 1173: Fecha: 24/03/2003, Caudal: 36.4
# Fila 1174: Fecha: 25/03/2003, Caudal: 46.7
# Fila 1175: Fecha: 26/03/2003, Caudal: 80.8
# Fila 1176: Fecha: 27/03/2003, Caudal: 87.3
# Fila 1177: Fecha: 28/03/2003, Caudal: 83.8
# Fila 1178: Fecha: 29/03/2003, Caudal: 88.6
# Fila 1179: Fecha: 30/03/2003, Caudal: 99.6
# Fila 1180: Fecha: 31/03/2003, Caudal: 288.7
# Fila 1181: Fecha: 01/04/2003, Caudal: 90.7
# Fila 1182: Fecha: 02/04/2003, Caudal: 58.9
# Fila 1183: Fecha: 03/04/2003, Caudal: 46.7
# Fila 1184: Fecha: 04/04/2003, Caudal: 43.8
# Fila 1185: Fecha: 05/04/2003, Caudal: 45.5
# Fila 1186: Fecha: 06/04/2003, Caudal: 44.3
# Fila 1187: Fecha: 07/04/2003, Caudal: 49.5
# ...

# %%
import pandas as pd
import datetime

# Abrir el archivo en modo lectura
with open('/content/drive/MyDrive/Colab Notebooks/SMWR_LEBRIJA_2.csv.txt', 'r') as file:
    # Leer todas las líneas del archivo
    lines = file.readlines()

# Crear un DataFrame con las fechas y caudales
data = []
for line in lines:
    datos = line.strip().split('\t')
    # Verificar si hay suficientes elementos en la línea
    if len(datos) >= 2:
        fecha = datetime.datetime.strptime(datos[0], '%d/%m/%Y')
        caudal = float(datos[1])
        data.append([fecha, caudal])

df = pd.DataFrame(data, columns=['Fecha', 'Caudal'])

# Convertir la columna 'Fecha' en el índice del DataFrame
df.set_index('Fecha', inplace=True)

# Caudales medios mensuales
caudal_medio_mensual = df.resample('M').mean()

# Caudales medios anuales
caudal_medio_anual = df.resample('Y').mean()

# Caudales medios mensuales multianuales
caudal_medio_mensual_multianual = df.resample('M').mean().rolling(window=12, min_periods=1).mean()

# Configurar pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Imprimir los resultados
print("Caudales medios mensuales:")
print(caudal_medio_mensual)
print("\nCaudales medios anuales:")
print(caudal_medio_anual)
# Out:
# Caudales medios mensuales:
#                 Caudal
# Fecha
# 2000-01-31  100.593548
# 2000-02-29  119.017241
# 2000-03-31  103.822581
# 2000-04-30  118.482759
# 2000-05-31  114.100000
# 2000-06-30  110.937931
# 2000-07-31   86.638710
# 2000-08-31   81.593548
# 2000-09-30  109.010000
# 2000-10-31  116.213333
# 2000-11-30  143.960000
# 2000-12-31   80.564516
# 2001-01-31   80.606452
# 2001-02-28   61.360714
# 2001-03-31   82.087097
# 2001-04-30   75.740000
# 2001-05-31  151.364516
# 2001-06-30   84.280000
# 2001-07-31   90.841935
# 2001-08-31   97.129032
# 2001-09-30   91.150000
# 2001-10-31  122.729032
# 2001-11-30  168.730000
# 2001-12-31  125.883871
# 2002-01-31   31.225806
# 2002-02-28   27.310714
# 2002-03-31   32.709677
# 2002-04-30   97.080000
# 2002-05-31   86.768966
# 2002-06-30   93.070000
# 2002-07-31   63.658065
# 2002-08-31   52.625806
# 2002-09-30   68.230000
# 2002-10-31   97.983333
# 2002-11-30   71.120000
# 2002-12-31   39.716129
# 2003-01-31   24.161290
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import datetime

# Crear un DataFrame con las fechas y caudales
data = []
for line in lines:
    datos = line.strip().split('\t')
    if len(datos) >= 2:
        fecha = datetime.datetime.strptime(datos[0], '%d/%m/%Y')
        caudal = float(datos[1])
        data.append([fecha, caudal])

df = pd.DataFrame(data, columns=['Fecha', 'Caudal'])

# Calcular el mes de cada fecha
df['Mes'] = df['Fecha'].dt.month

# Calcular el promedio de los caudales para cada mes
caudal_medio_mensual_multianual = df.groupby('Mes')['Caudal'].mean()

# Configurar pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Imprimir los resultados

print("Caudales medios mensuales multianuales:")
print(caudal_medio_mensual_multianual)
# Out:
# Caudales medios mensuales multianuales:
# Mes
# 1      55.436312
# 2      57.518408
# 3      70.483048
# 4     102.313937
# 5     123.578260
# 6      88.141295
# 7      67.890702
# 8      69.192994
# 9      86.386430
# 10    125.597457
# 11    148.855571
# 12     92.896317
# Name: Caudal, dtype: float64

# %% [markdown]
# 2_Realizar la estimación de los estadísticos o momentos de cada una de las 4 series.
# a. Media
# b. Varianza y desviación estándar
# c. Coeficiente de Variación
# d. Coeficiente de Asimetría
# e. Coeficiente de Curtosis
# f. Covarianza y Correlación
# g. Autocorrelación (ACF) y Autocorrelación parcial (PACF)
# h. La función de densidad espectral (PSD)

# %% [markdown]
# CAUDAL DIARIO

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.signal import periodogram

# Crear un DataFrame con las fechas y caudales
data = []

for line in lines:
    datos = line.strip().split('\t')
    if len(datos) >= 2:
        fecha = datetime.datetime.strptime(datos[0], '%d/%m/%Y')
        caudal = float(datos[1])
        data.append([fecha, caudal])

df = pd.DataFrame(data, columns=['Fecha', 'Caudal'])

# Convertir la columna 'Fecha' en el índice del DataFrame
df.set_index('Fecha', inplace=True)

# Estadísticos para los datos diarios de caudal
caudal_diario = df['Caudal']

# Media
media = caudal_diario.mean()

# Varianza y desviación estándar
varianza = caudal_diario.var()
desviacion_estandar = caudal_diario.std()

# Coeficiente de Variación
coeficiente_variacion = desviacion_estandar / media

# Coeficiente de Asimetría y Coeficiente de Curtosis
coeficiente_asimetria = caudal_diario.skew()
coeficiente_curtosis = caudal_diario.kurtosis()

# Covarianza y Correlación
covarianza = caudal_diario.cov(caudal_diario.shift())
correlacion = caudal_diario.corr(caudal_diario.shift())

# Autocorrelación (ACF) y Autocorrelación parcial (PACF)
acf = sm.tsa.acf(caudal_diario, nlags=40)
pacf = sm.tsa.pacf(caudal_diario, nlags=40)



# La función de densidad espectral (PSD)
f, Pxx = periodogram(caudal_diario)
plt.plot(f, Pxx)
plt.xlabel('Frecuencia')
plt.ylabel('Densidad Espectral')
plt.show()

# Imprimir los resultados

print("Media:", media)
print("Varianza:", varianza)
print("Desviación Estándar:", desviacion_estandar)
print("Coeficiente de Variación:", coeficiente_variacion)
print("Coeficiente de Asimetría:", coeficiente_asimetria)
print("Coeficiente de Curtosis:", coeficiente_curtosis)
print("Covarianza:", covarianza)
print("Correlación:", correlacion)
print("ACF:", acf)
print("PACF:", pacf)
# Out:
# Media: 90.78957826439579
# Varianza: 4974.9838319116625
# Desviación Estándar: 70.53356528569687
# Coeficiente de Variación: 0.7768905488280855
# Coeficiente de Asimetría: 2.1465446751487365
# Coeficiente de Curtosis: 5.783880690045274
# Covarianza: 3895.266774495076
# Correlación: 0.7829007060920168
# ACF: [1.         0.78284371 0.66936441 0.6189781  0.57618593 0.54037706
#  0.50636594 0.47791923 0.45340723 0.43358576 0.41722931 0.40619353
#  0.40033891 0.38557018 0.38455076 0.38507768 0.38086201 0.38707183
#  0.37452293 0.36231136 0.35068568 0.3490784  0.34529085 0.34526127
#  0.3331595  0.33125645 0.32808404 0.31339718 0.30455298 0.2976589
#  0.29799424 0.30265745 0.29385124 0.2932419  0.29088964 0.27930552
#  0.28258654 0.27820563 0.26897257 0.25754511 0.24746582]
# PACF: [ 1.00000000e+00  7.82970716e-01  1.46110564e-01  1.51088699e-01
#   7.48676392e-02  5.81042956e-02  3.29332797e-02  3.15694050e-02
#   2.60061094e-02  2.82315215e-02  2.73819862e-02  3.42956820e-02
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Asumiendo que 'caudal_diario' es tu serie de tiempo
# y 'axes' es una figura con dos ejes definidos
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

# Autocorrelación (ACF)
sm.graphics.tsa.plot_acf(caudal_diario, lags=40, ax=axes[0])

# Autocorrelación Parcial (PACF)
sm.graphics.tsa.plot_pacf(caudal_diario, lags=40, ax=axes[1])

plt.show()

# %% [markdown]
# Eje Y: En las gráficas de ACF y PACF, el eje Y representa el valor de la autocorrelación. Varía entre -1 y 1. Un valor de 1 indica una correlación positiva perfecta, mientras que -1 indica una correlación negativa perfecta. Si la línea de la gráfica toca el eje Y en 1 o -1, significa que hay una relación lineal perfecta entre los valores de la serie en los intervalos de tiempo correspondientes.
# Eje X: El eje X representa el número de retrasos (lags) para los cuales se calcula la autocorrelación. Por ejemplo, un lag de 1 significa que se está comparando la serie con ella misma un intervalo de tiempo atrás. En tu caso, el eje X llega hasta 40, lo que significa que estás viendo la autocorrelación para los primeros 40 lags.
# Barras en la Gráfica: Cada barra representa el valor de la autocorrelación para un lag específico. Si la barra se extiende hacia arriba y cruza el área sombreada (usualmente llamada “banda de confianza”), indica que la autocorrelación para ese lag es estadísticamente significativa.
# Interpretación: Si las primeras barras son significativas y luego disminuyen rápidamente, esto sugiere que la serie tiene una correlación a corto plazo. Si hay un patrón regular en las barras, como picos en intervalos específicos, esto puede indicar estacionalidad en los datos.

# %% [markdown]
# La gráfica de autocorrelación parcial (PACF) es similar a la ACF, pero con una diferencia clave: mientras que la ACF mide la correlación total entre los valores de la serie temporal separados por varios intervalos de tiempo, la PACF mide la correlación entre los valores de la serie temporal después de eliminar las correlaciones de los intervalos de tiempo intermedios.
#
# En otras palabras, la PACF te muestra la correlación entre un valor y su lag, excluyendo la influencia de los lags intermedios. Esto es útil para identificar la relación directa entre observaciones separadas por un número específico de periodos.
#
# Interpretación de la PACF:
#
# Eje Y: Representa el valor de la autocorrelación parcial, que también varía entre -1 y 1.
# Eje X: Muestra el número de lags. Por ejemplo, un valor en el eje X de 3 indica la correlación parcial con tres periodos de tiempo de diferencia.
# Barras Significativas: Si una barra cruza la banda de confianza (área sombreada), indica que la correlación parcial para ese lag es estadísticamente significativa y no se debe a la correlación con otros lags.
# La PACF es especialmente útil para determinar el orden de los modelos autorregresivos (AR), ya que te indica cuántos lags anteriores tienen una relación directa y significativa con el valor actual de la serie.

# %% [markdown]
# CAUDAL MEDIO MENSUAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.signal import periodogram

# Estadísticos para el caudal medio mensual
media_mensual = caudal_medio_mensual.mean()
varianza_mensual = caudal_medio_mensual.var()
desviacion_estandar_mensual = caudal_medio_mensual.std()
coeficiente_variacion_mensual = desviacion_estandar_mensual / media_mensual
coeficiente_asimetria_mensual = caudal_medio_mensual.skew()
coeficiente_curtosis_mensual = caudal_medio_mensual.kurtosis()
covarianza_mensual = caudal_medio_mensual.Caudal.cov(caudal_medio_mensual.Caudal.shift())
correlacion_mensual = caudal_medio_mensual.Caudal.corr(caudal_medio_mensual.Caudal.shift())
acf_mensual = sm.tsa.acf(caudal_medio_mensual.Caudal, nlags=10)
pacf_mensual = sm.tsa.pacf(caudal_medio_mensual.Caudal, nlags=10)

# La función de densidad espectral (PSD)
f_mensual, Pxx_mensual = periodogram(caudal_medio_mensual.Caudal)

# Imprimir los resultados
print("Caudales medios mensuales:")
print(caudal_medio_mensual)
print("\nMedia Mensual:", media_mensual)
print("Varianza Mensual:", varianza_mensual)
print("Desviación Estándar Mensual:", desviacion_estandar_mensual)
print("Coeficiente de Variación Mensual:", coeficiente_variacion_mensual)
print("Coeficiente de Asimetría Mensual:", coeficiente_asimetria_mensual)
print("Coeficiente de Curtosis Mensual:", coeficiente_curtosis_mensual)
print("Covarianza Mensual:", covarianza_mensual)
print("Correlación Mensual:", correlacion_mensual)
print("ACF:", acf_mensual)
print("PACF:", pacf_mensual)

# Visualización de la PSD
plt.plot(f_mensual, Pxx_mensual)
plt.xlabel('Frecuencia')
plt.ylabel('Densidad Espectral')
plt.show()
# Out:
# Caudales medios mensuales:
#                 Caudal
# Fecha
# 2000-01-31  100.593548
# 2000-02-29  119.017241
# 2000-03-31  103.822581
# 2000-04-30  118.482759
# 2000-05-31  114.100000
# 2000-06-30  110.937931
# 2000-07-31   86.638710
# 2000-08-31   81.593548
# 2000-09-30  109.010000
# 2000-10-31  116.213333
# 2000-11-30  143.960000
# 2000-12-31   80.564516
# 2001-01-31   80.606452
# 2001-02-28   61.360714
# 2001-03-31   82.087097
# 2001-04-30   75.740000
# 2001-05-31  151.364516
# 2001-06-30   84.280000
# 2001-07-31   90.841935
# 2001-08-31   97.129032
# 2001-09-30   91.150000
# 2001-10-31  122.729032
# 2001-11-30  168.730000
# 2001-12-31  125.883871
# 2002-01-31   31.225806
# 2002-02-28   27.310714
# 2002-03-31   32.709677
# 2002-04-30   97.080000
# 2002-05-31   86.768966
# 2002-06-30   93.070000
# 2002-07-31   63.658065
# 2002-08-31   52.625806
# 2002-09-30   68.230000
# 2002-10-31   97.983333
# 2002-11-30   71.120000
# 2002-12-31   39.716129
# 2003-01-31   24.161290
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Leer el archivo CSV
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SMWR_LEBRIJA_2.csv.txt', sep='\t', header=None, names=['Fecha', 'Caudal'], parse_dates=['Fecha'], dayfirst=True, date_parser=lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# Convertir la columna 'Fecha' en el índice del DataFrame
df.set_index('Fecha', inplace=True)

# Caudales medios mensuales
caudal_medio_mensual = df.resample('M').mean()['Caudal']

# Calcular la ACF y PACF del caudal medio mensual
acf_mensual = sm.tsa.acf(caudal_medio_mensual, nlags=4)
pacf_mensual = sm.tsa.pacf(caudal_medio_mensual, nlags=4)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF
sm.graphics.tsa.plot_acf(caudal_medio_mensual, lags=12, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Mensual')

# Graficar la PACF
sm.graphics.tsa.plot_pacf(caudal_medio_mensual, lags=4, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Mensual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()
# Out:
# <ipython-input-15-ddf47261e282>:6: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SMWR_LEBRIJA_2.csv.txt', sep='\t', header=None, names=['Fecha', 'Caudal'], parse_dates=['Fecha'], dayfirst=True, date_parser=lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# %% [markdown]
# CAUDAL MEDIO ANUAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.signal import periodogram


# Calculate annual mean flow
caudal_medio_anual = df.resample('Y').mean()


# Estadísticos para el caudal medio anual
media_anual = caudal_medio_anual.mean()
varianza_anual = caudal_medio_anual.var()
desviacion_estandar_anual = caudal_medio_anual.std()
coeficiente_variacion_anual = desviacion_estandar_anual / media_anual
coeficiente_asimetria_anual = caudal_medio_anual.skew()
coeficiente_curtosis_anual = caudal_medio_anual.kurtosis()
covarianza_anual = caudal_medio_anual.Caudal.cov(caudal_medio_anual.Caudal.shift())
correlacion_anual = caudal_medio_anual.Caudal.corr(caudal_medio_anual.Caudal.shift())
acf_anual = sm.tsa.acf(caudal_medio_anual.Caudal, nlags=4)
pacf_anual = sm.tsa.pacf(caudal_medio_anual.Caudal, nlags=4)

# La función de densidad espectral (PSD)
f_anual, Pxx_anual = periodogram(caudal_medio_anual.Caudal)

# Imprimir los resultados
print("Caudales medios anuales:")
print(caudal_medio_anual)
print("\nMedia Anual:", media_anual)
print("Varianza Anual:", varianza_anual)
print("Desviación Estándar Anual:", desviacion_estandar_anual)
print("Coeficiente de Variación Anual:", coeficiente_variacion_anual)
print("Coeficiente de Asimetría Anual:", coeficiente_asimetria_anual)
print("Coeficiente de Curtosis Anual:", coeficiente_curtosis_anual)
print("Covarianza Anual:", covarianza_anual)
print("Correlación Anual:", correlacion_anual)
print("ACF:", acf_anual)
print("PACF:", pacf_anual)

# Visualización de la PSD
plt.plot(f_anual, Pxx_anual)
plt.xlabel('Frecuencia')
plt.ylabel('Densidad Espectral')
plt.show()

# Caudales medios anuales
caudal_medio_anual= df.resample('Y').mean()['Caudal']


# Calcular la ACF y PACF del caudal medio anual
acf_anual = sm.tsa.acf(caudal_medio_anual, nlags=4)
pacf_anual = sm.tsa.pacf(caudal_medio_anual, nlags=4)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF
sm.graphics.tsa.plot_acf(caudal_medio_anual, lags=4, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Anual')

# Graficar la PACF
sm.graphics.tsa.plot_pacf(caudal_medio_anual, lags=4, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Anual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()
# Out:
# Caudales medios anuales:
#                 Caudal
# Fecha
# 2000-12-31  106.795868
# 2001-12-31  102.972603
# 2002-12-31   63.324586
# 2003-12-31   90.158630
# 2004-12-31   77.767313
# 2005-12-31   93.945730
# 2006-12-31   74.956703
# 2007-12-31   76.046356
# 2008-12-31   99.401753
# 2009-12-31   98.119719
# 2010-12-31  150.687890
# 2011-12-31  157.321409
# 2012-12-31   91.615397
# 2013-12-31   90.535069
# 2014-12-31   72.996088
# 2015-12-31   46.038515
# 2016-12-31   49.629141
#
# Media Anual: Caudal    90.724281
# dtype: float64
# Varianza Anual: Caudal    872.703068
# dtype: float64
# Desviación Estándar Anual: Caudal    29.541548
# dtype: float64
# Coeficiente de Variación Anual: Caudal    0.325619
# dtype: float64
# Coeficiente de Asimetría Anual: Caudal    0.890265
# dtype: float64
# Coeficiente de Curtosis Anual: Caudal    1.166077
# dtype: float64
# Covarianza Anual: 475.2681398165912
# Correlación Anual: 0.5523593022148445
# ...

# %% [markdown]
# CAUDAL MEDIO MULTIANUAL

# %%
# Estadísticos para el caudal medio anual
media_anual = caudal_medio_mensual_multianual.mean()
varianza_anual = caudal_medio_mensual_multianual.var()
desviacion_estandar_anual = caudal_medio_mensual_multianual.std()
coeficiente_variacion_anual = desviacion_estandar_anual / media_anual
coeficiente_asimetria_anual = caudal_medio_mensual_multianual.skew()
coeficiente_curtosis_anual = caudal_medio_mensual_multianual.kurtosis()
covarianza_anual = caudal_medio_mensual_multianual.cov(caudal_medio_mensual_multianual.shift())
correlacion_anual = caudal_medio_mensual_multianual.corr(caudal_medio_mensual_multianual.shift())
acf_anual = sm.tsa.acf(caudal_medio_mensual_multianual, nlags=4)
pacf_anual = sm.tsa.pacf(caudal_medio_mensual_multianual, nlags=4)

# La función de densidad espectral (PSD)
f_anual, Pxx_anual = periodogram(caudal_medio_mensual_multianual)

# Imprimir los resultados
print("Caudales medios anuales:")
print(caudal_medio_mensual_multianual)
print("\nMedia Anual:", media_anual)
print("Varianza Anual:", varianza_anual)
print("Desviación Estándar Anual:", desviacion_estandar_anual)
print("Coeficiente de Variación Anual:", coeficiente_variacion_anual)
print("Coeficiente de Asimetría Anual:", coeficiente_asimetria_anual)
print("Coeficiente de Curtosis Anual:", coeficiente_curtosis_anual)
print("Covarianza Anual:", covarianza_anual)
print("Correlación Anual:", correlacion_anual)
print("ACF:", acf_anual)
print("PACF:", pacf_anual)

# Visualización de la PSD
plt.plot(f_anual, Pxx_anual)
plt.xlabel('Frecuencia')
plt.ylabel('Densidad Espectral')
plt.show()

# Calcular la ACF y PACF del caudal medio anual
acf_anual = sm.tsa.acf(caudal_medio_mensual_multianual, nlags=4)
pacf_anual = sm.tsa.pacf(caudal_medio_mensual_multianual, nlags=4)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF
sm.graphics.tsa.plot_acf(caudal_medio_mensual_multianual, lags=4, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Anual')

# Graficar la PACF
sm.graphics.tsa.plot_pacf(caudal_medio_mensual_multianual, lags=4, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Anual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()
# Out:
# Caudales medios anuales:
# Mes
# 1      55.436312
# 2      57.518408
# 3      70.483048
# 4     102.313937
# 5     123.578260
# 6      88.141295
# 7      67.890702
# 8      69.192994
# 9      86.386430
# 10    125.597457
# 11    148.855571
# 12     92.896317
# Name: Caudal, dtype: float64
#
# Media Anual: 90.6908941553893
# Varianza Anual: 871.0754020484186
# Desviación Estándar Anual: 29.513986549573723
# Coeficiente de Variación Anual: 0.32543494938978784
# Coeficiente de Asimetría Anual: 0.7044112199446981
# Coeficiente de Curtosis Anual: -0.39388846556287094
# Covarianza Anual: 455.95970901110707
# Correlación Anual: 0.5137234456510225
# ACF: [ 1.          0.47512104 -0.19704478 -0.46609361 -0.25758338]
# PACF: [ 1.          0.51831387 -0.690644   -0.14715416  0.10287098]

# %% [markdown]
# GRAFICA SERIES DE TIEMPO

# %%
import matplotlib.pyplot as plt

# Crear una figura con subgráficos
fig, axs = plt.subplots(4, 1, figsize=(12, 16))


df = pd.DataFrame(data, columns=['Fecha', 'Caudal'])

# Convertir la columna 'Fecha' en el índice del DataFrame
df.set_index('Fecha', inplace=True)
# Graficar caudal diario
axs[0].plot(df.index, df['Caudal'], label='Caudal Diario', color='blue')
axs[0].set_title('Caudal Diario')
axs[0].set_xlabel('Fecha')
axs[0].set_ylabel('Caudal')
axs[0].legend()

# Graficar caudal medio mensual
axs[1].plot(caudal_medio_mensual.index, caudal_medio_mensual, label='Caudal Medio Mensual', color='green')
axs[1].set_title('Caudal Medio Mensual')
axs[1].set_xlabel('Fecha')
axs[1].set_ylabel('Caudal Medio')
axs[1].legend()

# Graficar caudal medio mensual multianual
axs[2].plot(caudal_medio_mensual_multianual.index, caudal_medio_mensual_multianual, label='Caudal Medio Mensual Multianual', color='orange')
axs[2].set_title('Caudal Medio Mensual Multianual')
axs[2].set_xlabel('Fecha')
axs[2].set_ylabel('Caudal Medio')
axs[2].legend()

# Graficar caudal medio anual
axs[3].plot(caudal_medio_mensual_multianual.index, caudal_medio_mensual_multianual, label='Caudal Medio Anual', color='red')
axs[3].set_title('Caudal Medio Anual')
axs[3].set_xlabel('Fecha')
axs[3].set_ylabel('Caudal Medio')
axs[3].legend()

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %% [markdown]
# El correlograma total de cada serie de tiempo

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Calcular la ACF y PACF del caudal diario
acf_diario = sm.tsa.acf(df['Caudal'], nlags=40)
pacf_diario = sm.tsa.pacf(df['Caudal'], nlags=40)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF del caudal diario
sm.graphics.tsa.plot_acf(df['Caudal'], lags=40, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Diario')

# Graficar la PACF del caudal diario
sm.graphics.tsa.plot_pacf(df['Caudal'], lags=40, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Diario')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %%
# Calcular la ACF y PACF del caudal medio mensual
acf_mensual = sm.tsa.acf(caudal_medio_mensual, nlags=10)
pacf_mensual = sm.tsa.pacf(caudal_medio_mensual, nlags=10)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF del caudal medio mensual
sm.graphics.tsa.plot_acf(caudal_medio_mensual, lags=10, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Mensual')

# Graficar la PACF del caudal medio mensual
sm.graphics.tsa.plot_pacf(caudal_medio_mensual, lags=10, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Mensual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %%
# Calcular la ACF y PACF del caudal medio anual
acf_anual = sm.tsa.acf(caudal_medio_anual, nlags=4)
pacf_anual = sm.tsa.pacf(caudal_medio_anual, nlags=4)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF del caudal medio anual
sm.graphics.tsa.plot_acf(caudal_medio_anual, lags=4, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Anual')

# Graficar la PACF del caudal medio anual
sm.graphics.tsa.plot_pacf(caudal_medio_anual, lags=4, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Anual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %%
# Calcular la ACF y PACF del caudal medio mensual anual
acf_mensual_anual = sm.tsa.acf(caudal_medio_mensual_multianual, nlags=4)
pacf_mensual_anual = sm.tsa.pacf(caudal_medio_mensual_multianual, nlags=4)

# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Graficar la ACF del caudal medio mensual anual
sm.graphics.tsa.plot_acf(caudal_medio_mensual_multianual, lags=4, ax=ax1)
ax1.set_title('Autocorrelación del Caudal Medio Mensual Multi Anual')

# Graficar la PACF del caudal medio mensual anual
sm.graphics.tsa.plot_pacf(caudal_medio_mensual_multianual, lags=4, ax=ax2)
ax2.set_title('Autocorrelación Parcial del Caudal Medio Multi Mensual Anual')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %% [markdown]
# DESVIACION ESTANDAR

# %%
import matplotlib.pyplot as plt

# Calcular las desviaciones estándar
desviacion_estandar_diario = df['Caudal'].std()
desviacion_estandar_mensual = caudal_medio_mensual.std()
desviacion_estandar_anual = caudal_medio_anual.std()
desviacion_estandar_multianual = caudal_medio_mensual_multianual.std()

# Crear una figura y ejes para el gráfico
fig, ax = plt.subplots()

# Etiquetas para cada serie de tiempo
series = ['Caudal Medio Diario','Caudal Medio Mensual', 'Caudal Medio Anual', 'Caudal Medio Multianual']

# Valores de las desviaciones estándar
desviaciones = [float(desviacion_estandar_diario),float(desviacion_estandar_mensual), float(desviacion_estandar_anual), float(desviacion_estandar_multianual)]

# Crear el gráfico de barras
ax.bar(series, desviaciones, color=['blue','green', 'red', 'yellow'])

# Etiquetas y título
ax.set_xlabel('Serie de Tiempo')
ax.set_ylabel('Desviación Estándar')
ax.set_title('Desviación Estándar de las Series de Tiempo')
ax.tick_params(axis='x', rotation=45)  # Rotar etiquetas del eje x

# Mostrar el gráfico
plt.show()

# %% [markdown]
# COEFICIENTE DE ASIMETRÍA

# %%
import matplotlib.pyplot as plt
import numpy as np
# Coeficiente de Asimetría y Coeficiente de Curtosis
coeficiente_asimetria_diario = caudal_diario.skew()
coeficiente_curtosis_diario = caudal_diario.kurtosis()

coeficiente_asimetria_mensual = caudal_medio_mensual.skew()
coeficiente_curtosis_mensual = caudal_medio_mensual.kurtosis()

coeficiente_asimetria_anual = caudal_medio_anual.skew()
coeficiente_curtosis_anual = caudal_medio_anual.kurtosis()

coeficiente_asimetria_mensual_multianual = caudal_medio_mensual_multianual.skew()
coeficiente_curtosis_mensual_anual = caudal_medio_mensual_multianual.kurtosis()
# Coeficientes de asimetría
coeficientes_asimetria = [
    float(coeficiente_asimetria_diario),
    float(coeficiente_asimetria_mensual),
    float(coeficiente_asimetria_anual),
    float(coeficiente_asimetria_mensual_multianual)
]

# Etiquetas para cada serie de tiempo
series = [
    'Caudal Diario',
    'Caudal Medio Mensual',
    'Caudal Medio Anual',
    'Caudal Medio Mensual Multianual'
]

# Crear una figura y ejes para el gráfico
fig, ax = plt.subplots()

# Crear el gráfico de barras
ax.bar(series, coeficientes_asimetria, color=['blue', 'green', 'red', 'purple'])

# Etiquetas y título
ax.set_xlabel('Serie de Tiempo')
ax.set_ylabel('Coeficiente de Asimetría')
ax.set_title('Coeficiente de Asimetría de las Series de Tiempo')
ax.tick_params(axis='x', rotation=45)  # Rotar etiquetas del eje x

# Mostrar el gráfico
# Mostrar el gráfico
plt.show()

# %% [markdown]
# COEFICIENTE DE CURTOSIS

# %%
import matplotlib.pyplot as plt

coeficientes_curtosis = [
    float(coeficiente_curtosis_diario),
    float(coeficiente_curtosis_mensual),
    float(coeficiente_curtosis_anual),
    float(coeficiente_curtosis_mensual_anual)
]

# Etiquetas para cada serie de tiempo
series = [
    'Caudal Diario',
    'Caudal Medio Mensual',
    'Caudal Medio Anual',
    'Caudal Medio Mensual Multianual'
]

# Crear una figura y ejes para el gráfico de curtosis
fig, ax2 = plt.subplots()
ax2.bar(series, coeficientes_curtosis, color='red')
ax2.set_ylabel('Coeficiente de Curtosis')
ax2.set_title('Coeficiente de Curtosis de las Series de Tiempo')
ax2.tick_params(axis='x', rotation=45)  # Rotar etiquetas del eje x

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Suponiendo que tienes las series de tiempo 'caudal_diario', 'caudal_medio_mensual', 'caudal_medio_anual' y 'caudal_medio_mensual_multianual'

# Crear una figura y ejes para el gráfico de periodogramas
fig, axs = plt.subplots(4, 1, figsize=(4, 12))

for i, serie in enumerate(['caudal_diario', 'caudal_medio_mensual', 'caudal_medio_anual', 'caudal_medio_mensual_multianual']):
    # Calcular el periodograma para la serie de tiempo actual
    periodograma = np.abs(np.fft.fft(eval(serie)))**2

    # Frecuencias correspondientes al periodograma
    frecuencias = np.fft.fftfreq(len(eval(serie)))

    # Graficar el periodograma en la subtrama correspondiente
    axs[i].plot(frecuencias[:len(frecuencias)//2], periodograma[:len(frecuencias)//2], color='blue')
    axs[i].set_xlabel('Frecuencia')
    axs[i].set_ylabel('Potencia')
    axs[i].set_title(f'Periodograma de {serie}')
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# %%
pip install EMD-signal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from PyEMD import EMD
import matplotlib.pyplot as plt

# Crear una instancia de EMD
emd = EMD()

# Convertir la serie de tiempo a un arreglo de numpy
caudal_diario_array = caudal_diario.values

# Aplicar EMD a la serie de tiempo
imf = emd(caudal_diario_array)

# Graficar las curvas IMF resultantes
plt.figure(figsize=(12, 6))
for i, curva in enumerate(imf):
    plt.plot(curva, label=f'IMF{i+1}')
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.title('Curvas IMF obtenidas con EMD')
plt.legend()
plt.show()

# %%
import numpy as np
from PyEMD import EMD
import matplotlib.pyplot as plt

# Crear una instancia de EMD
emd = EMD()

# Convertir la serie de tiempo a un arreglo de numpy
caudal_medio_mensual_array = caudal_medio_mensual.values

# Aplicar EMD a la serie de tiempo
imf = emd(caudal_medio_mensual_array)

# Graficar las curvas IMF resultantes
plt.figure(figsize=(12, 6))
for i, curva in enumerate(imf):
    plt.plot(curva, label=f'IMF{i+1}')
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.title('Curvas IMF obtenidas con EMD')
plt.legend()
plt.show()

# %%
import numpy as np
from PyEMD import EMD
import matplotlib.pyplot as plt
# Crear una instancia de EMD
emd = EMD()

# Convertir la serie de tiempo a un arreglo de numpy
caudal_medio_anual_array = caudal_medio_anual.values

# Aplicar EMD a la serie de tiempo
imf = emd(caudal_medio_anual_array)

# Graficar las curvas IMF resultantes
plt.figure(figsize=(12, 6))
for i, curva in enumerate(imf):
    plt.plot(curva, label=f'IMF{i+1}')
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.title('Curvas IMF obtenidas con EMD')
plt.legend()
plt.show()

# %%
import numpy as np
from PyEMD import EMD
import matplotlib.pyplot as plt

# Crear una instancia de EMD
emd = EMD()

# Convertir la serie de tiempo a un arreglo de numpy
caudal_medio_mensual_multianual_array = caudal_medio_mensual_multianual.values

# Aplicar EMD a la serie de tiempo
imf = emd(caudal_medio_mensual_multianual_array)

# Graficar las curvas IMF resultantes
plt.figure(figsize=(12, 6))
for i, curva in enumerate(imf):
    plt.plot(curva, label=f'IMF{i+1}')
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.title('Curvas IMF obtenidas con EMD')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


fig, axs = plt.subplots(4, 1, figsize=(8, 24))

for i, serie in enumerate([caudal_diario, caudal_medio_mensual, caudal_medio_anual, caudal_medio_mensual_multianual]):
    # Graficar el histograma en la subtrama correspondiente
    axs[i].hist(serie, bins=30, color='blue', alpha=0.7)
    axs[i].set_xlabel('Valor')
    axs[i].set_ylabel('Frecuencia')
    axs[i].set_title(f'Histograma de la Serie de Tiempo {i+1}')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# las series de tiempo 'caudal_diario', 'caudal_medio_mensual', 'caudal_medio_anual' y 'caudal_medio_mensual_multianual'

# Crear una figura y ejes para el gráfico de diagramas de caja y bigotes
fig, axs = plt.subplots(4, 1, figsize=(4, 12))

for i, serie in enumerate([caudal_diario, caudal_medio_mensual, caudal_medio_anual, caudal_medio_mensual_multianual]):
    # Graficar el diagrama de caja y bigotes en la subtrama correspondiente
    axs[i].boxplot(serie, vert=False, patch_artist=True, boxprops=dict(facecolor='blue', color='black'))
    axs[i].set_xlabel('Valor')
    axs[i].set_ylabel('Serie de Tiempo')
    axs[i].set_title(f'Diagrama de Caja y Bigotes de la Serie de Tiempo {i+1}')

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Realice las pruebas de hipótesis de cada una de las cuatro series de tiempo
# a. Análisis de saltos
# i. Prueba pettitt

# %%
import numpy as np
from scipy.stats import norm

def pettitt_test(data):
    n = len(data)
    k = np.zeros((n, n))
    for i in range(n):
        for j in range(i+1, n):
            k[i, j] = np.sign(data[j] - data[i])
    s = np.sum(k)
    v = np.var(k.flatten())
    z = s / np.sqrt((n*(n-1)*(2*n+5)) / 18)
    p_value = 2 * (1 - norm.cdf(abs(z)))
    return z, p_value

# Suponiendo que 'serie_tiempo' es tu serie de tiempo
z, p_value = pettitt_test(caudal_diario)

if p_value <= 0.05:
    print("Se rechaza la hipótesis nula de que no hay cambio abrupto en la serie de tiempo de caudal diario.")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula.")
# Out:
# Se rechaza la hipótesis nula de que no hay cambio abrupto en la serie de tiempo de caudal diario.

# %%
# Suponiendo que 'serie_tiempo' es tu serie de tiempo
z, p_value = pettitt_test(caudal_medio_mensual)

if p_value <= 0.05:
    print("Se rechaza la hipótesis nula de que no hay cambio abrupto en la serie de tiempo Caudal Medio Mensual.")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula.")
# Out:
# Se rechaza la hipótesis nula de que no hay cambio abrupto en la serie de tiempo Caudal Medio Mensual.

# %%
# Suponiendo que 'serie_tiempo' es tu serie de tiempo
z, p_value = pettitt_test(caudal_medio_anual)

if p_value <= 0.05:
    print("Se rechaza la hipótesis nula de que no hay cambio abrupto en la serie de tiempo Caudal medio anual.")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula.")
# Out:
# No hay suficiente evidencia para rechazar la hipótesis nula.

# %%
import pandas as pd
from scipy.stats import ranksums

# Carga los datos desde tu archivo (reemplaza 'ruta_del_archivo.csv' con la ubicación real)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SMWR_LEBRIJA_2.csv.txt')

# Divide los datos en dos grupos (por ejemplo, antes y después de un tratamiento)
mitad = len(df) // 2
grupo_a = df[:mitad]
grupo_b = df[mitad:]

estadistica, p = ranksums(grupo_a, grupo_b)
print(f"Estadistica de prueba: {estadistica}, valor p: {p}")
# Out:
# Estadistica de prueba: [25.12337647], valor p: [2.76250319e-139]
